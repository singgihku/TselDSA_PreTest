# %%
#Mount Google Drive to Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Change Directory
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/Tsel_DSA/03_PreTest/')
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Tsel_DSA/03_PreTest'

# %%
#import packages
import numpy as np
import pandas as pd
import statistics as st

# %%
#Load file
df = pd.read_csv("churn.csv", encoding='latin1')

# %%
df.shape
# Out:
# (5000, 21)

# %%
df.head(3)
# Out:
#    state  account_length  ...  number_customer_service_calls  class
# 0     16             128  ...                              1      0
# 1     35             107  ...                              1      0
# 2     31             137  ...                              0      0
#
# [3 rows x 21 columns]

# %%
#Show Data Profile
Data_dict = pd.DataFrame(df.dtypes)
Data_dict = Data_dict.rename(columns={0:'Data_Type'})
Data_dict['Missing_Value'] = df.isnull().sum()
Data_dict['Unique_Value'] = df.nunique()
Data_dict['Count'] = df.count()
Data_dict
# Out:
#                               Data_Type  Missing_Value  Unique_Value  Count
# state                             int64              0            51   5000
# account_length                    int64              0           218   5000
# area_code                         int64              0             3   5000
# phone_number                      int64              0          5000   5000
# international_plan                int64              0             2   5000
# voice_mail_plan                   int64              0             2   5000
# number_vmail_messages             int64              0            48   5000
# total_day_minutes               float64              0          1961   5000
# total_day_calls                   int64              0           123   5000
# total_day_charge                float64              0          1961   5000
# total_eve_minutes               float64              0          1879   5000
# ...

# %%
df=df.rename(columns={'class':'churn'})

# %%
df.churn.value_counts()
# Out:
# 0    4293
# 1     707
# Name: churn, dtype: int64

# %% [markdown]
# ### Top 3 State yang Customer nya paling banyak churn

# %%
df[df.churn==1].state.value_counts().sort_values(ascending=False).head(3)
# Out:
# 31    28
# 43    26
# 47    24
# Name: state, dtype: int64

# %% [markdown]
# ### Top 3 Area code yang Customer nya paling banyak churn

# %%
df[df.churn==1].area_code.value_counts().sort_values(ascending=False).head(3)
# Out:
# 415    346
# 510    184
# 408    177
# Name: area_code, dtype: int64

# %% [markdown]
# ### Perbedaan antara churn dan stay customer

# %%
df_churn = df[df['churn']==1]
df_notchurn = df[df['churn']==0]

# %%
df_churn.mean().round(2)
# Out:
# state                              26.25
# account_length                    102.33
# area_code                         437.97
# phone_number                     2543.50
# international_plan                  0.28
# voice_mail_plan                     0.14
# number_vmail_messages               4.50
# total_day_minutes                 207.87
# total_day_calls                   100.82
# total_day_charge                   35.34
# total_eve_minutes                 211.76
# total_eve_calls                    99.88
# total_eve_charge                   18.00
# total_night_minutes               206.08
# total_night_calls                  99.58
# total_night_charge                  9.27
# total_intl_minutes                 10.69
# total_intl_calls                    4.15
# total_intl_charge                   2.89
# number_customer_service_calls       2.25
# churn                               1.00
# dtype: float64

# %%
df_notchurn.mean().round(2)
# Out:
# state                              25.96
# account_length                     99.92
# area_code                         436.74
# phone_number                     2492.25
# international_plan                  0.06
# voice_mail_plan                     0.28
# number_vmail_messages               8.29
# total_day_minutes                 175.75
# total_day_calls                    99.90
# total_day_charge                   29.88
# total_eve_minutes                 198.81
# total_eve_calls                   100.24
# total_eve_charge                   16.90
# total_night_minutes               199.46
# total_night_calls                  99.98
# total_night_charge                  8.98
# total_intl_minutes                 10.19
# total_intl_calls                    4.48
# total_intl_charge                   2.75
# number_customer_service_calls       1.46
# churn                               0.00
# dtype: float64

# %% [markdown]
# 1. Churn customers having day calls more than stay customers
# 2. Churn customers having eve calls more than stay customers
# 3. Churn customers having night calls more than stay customers
# 4. Churn customers have number_vmail_messages less  than stay customers
# 5. Churn customers have number_customer_service_calls more than stay customers
# 6. Churn customers have account_length more than stay customers
# 7. Churn customers have international_plan more than stay customers
# 8. Churn customers have voice_mail_plan less than stay customers

# %% [markdown]
# ### ARPU pelanggan yang churn

# %%
df_churn['revenue']=df_churn.international_plan+df_churn.voice_mail_plan+df_churn.total_day_charge+df_churn.total_night_charge+df_churn.total_intl_charge
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_churn.revenue.mean()
# Out:
# 47.92519094766619

# %% [markdown]
# ### ARPU pelanggan yang stay

# %%
df_notchurn['revenue']=df_notchurn.international_plan+df_notchurn.voice_mail_plan+df_notchurn.total_day_charge+df_notchurn.total_night_charge+df_notchurn.total_intl_charge
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_notchurn.revenue.mean()
# Out:
# 41.9533822501746

# %% [markdown]
# ### Variable yang paling mempengaruhi pelanggan churn

# %%
df.corr(method='pearson').churn.sort_values(ascending=False)
# Out:
# churn                            1.000000
# international_plan               0.259123
# number_customer_service_calls    0.212564
# total_day_minutes                0.207705
# total_day_charge                 0.207700
# total_eve_minutes                0.089288
# total_eve_charge                 0.089282
# total_intl_minutes               0.063285
# total_intl_charge                0.063275
# total_night_minutes              0.045677
# total_night_charge               0.045673
# account_length                   0.021203
# total_day_calls                  0.016130
# phone_number                     0.012371
# area_code                        0.010195
# state                            0.006946
# total_eve_calls                 -0.006284
# total_night_calls               -0.006986
# total_intl_calls                -0.046893
# number_vmail_messages           -0.097633
# voice_mail_plan                 -0.110698
# Name: churn, dtype: float64
